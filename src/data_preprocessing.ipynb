# %% [markdown]
# ## Data Preprocessing Python Script
# - File stored as CSV from Webscraping Script is converted to parquet file
# - Standard Format like 200-301 and MMLU Dataset
# - 350-701 Cisco CCNP Questions
#     - 140 Question
#     - Containing Images encoded base64
#     - Also dataset without images

# %%
from pandas import read_csv
import pandas as pd
import ast

# %%
ccnp_350_701 = read_csv('/home/iai/sb7059/git/llm_test/archive/raw_data/extracted_questions_answers_350_701.csv')
ccna_200_301 = pd.read_parquet('/home/iai/sb7059/git/llm_test/data/201-301-CCNA.parquet')

# %%
ccnp_350_701
# Out:
#                                               Question  \
# 0    Which functions of an SDN architecture require...
# 1    Which two request methods of REST API are vali...
# 2    The main function of northbound APIs in the SD...
# 3    What is a feature of the open platform capabil...
# 4    Refer to the exhibit. What does the API do whe...
# ..                                                 ...
# 135  An engineer has been tasked with configuring a...
# 136  An organization uses Cisco FMC to centrally ma...
# 137  An administrator is establishing a new site-to...
# 138  A Cisco FTD engineer is creating a newIKEv2 po...
# 139  What is a functional difference between a Cisc...
#
#                                                Answers Correct Answer  \
# 0    ['SDN controller and the network elements', 'm...              A
# 1         ['put', 'options', 'get', 'push', 'connect']             AC
# 2    ['SDN controller and the cloud', 'management c...              D
# 3    ['application adapters', 'domain integration',...              C
# 4    ['create an SNMP pull mechanism for managing A...              D
# ..                                                 ...            ...
# 135  ['Enable traffic analysis in the Cisco FTD.', ...              C
# 136  ['Change the management port on Cisco FMC so t...              C
# 137  ['crypto isakmp identity address 172.19.20.24'...              D
# 138  ['Change the encryption to AES* to support all...              D
# 139  ['The Cisco ASA can be configured for high ava...              C
#
#                                                  Image
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    iVBORw0KGgoAAAANSUhEUgAAAgsAAAGmCAIAAAB9V1A0AA...
# ..                                                 ...
# 135                                                NaN
# 136                                                NaN
# 137                                                NaN
# 138                                                NaN
# 139                                                NaN
#
# [140 rows x 4 columns]

# %%
#Rename columns from Question to question and Answers to choices Correct Answer to answer
ccnp_350_701 = ccnp_350_701.rename(columns={'Question': 'question', 'Answers': 'choices', 'Correct Answer': 'answer', 'Image': 'image'})

# %%
#Change column choices to pandas.core.series.Series
ccnp_350_701['choices'] = ccnp_350_701['choices'].apply(lambda x: pd.Series(x))

# %%
#Add a whitespace to the string of the column answers if there are more than one answer like AB or ABC to A B or A B C
ccnp_350_701['answer'] = ccnp_350_701['answer'].apply(lambda x: ' '.join(list(x)) if isinstance(x, str) else x)

# %%
#Convert the letters given in column answers to a pandas series of numbers, like: A=0, B=1, C=2, D=3 or A B = 0,1
def convert_to_number(x):
    if isinstance(x, str):
        return [ord(i) - 65 for i in x.split()]
    else:
        return x

ccnp_350_701['answer'] = ccnp_350_701['answer'].apply(convert_to_number)

# %%
#Convert to string ao actual lists
ccnp_350_701['choices'] = ccnp_350_701['choices'].apply(lambda x: [i.strip() for i in ast.literal_eval(x)])
ccnp_350_701['choices'] = ccnp_350_701['choices'].apply(lambda x: [i.strip() for i in x])

# %%
ccnp_350_701
# Out:
#                                               question  \
# 0    Which functions of an SDN architecture require...
# 1    Which two request methods of REST API are vali...
# 2    The main function of northbound APIs in the SD...
# 3    What is a feature of the open platform capabil...
# 4    Refer to the exhibit. What does the API do whe...
# ..                                                 ...
# 135  An engineer has been tasked with configuring a...
# 136  An organization uses Cisco FMC to centrally ma...
# 137  An administrator is establishing a new site-to...
# 138  A Cisco FTD engineer is creating a newIKEv2 po...
# 139  What is a functional difference between a Cisc...
#
#                                                choices  answer  \
# 0    [SDN controller and the network elements, mana...     [0]
# 1                   [put, options, get, push, connect]  [0, 2]
# 2    [SDN controller and the cloud, management cons...     [3]
# 3    [application adapters, domain integration, int...     [2]
# 4    [create an SNMP pull mechanism for managing AM...     [3]
# ..                                                 ...     ...
# 135  [Enable traffic analysis in the Cisco FTD., Im...     [2]
# 136  [Change the management port on Cisco FMC so th...     [2]
# 137  [crypto isakmp identity address 172.19.20.24, ...     [3]
# 138  [Change the encryption to AES* to support all ...     [3]
# 139  [The Cisco ASA can be configured for high avai...     [2]
#
#                                                  image
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    iVBORw0KGgoAAAANSUhEUgAAAgsAAAGmCAIAAAB9V1A0AA...
# ..                                                 ...
# 135                                                NaN
# 136                                                NaN
# 137                                                NaN
# 138                                                NaN
# 139                                                NaN
#
# [140 rows x 4 columns]

# %%
#Add a column with the exam name
ccnp_350_701['exam'] = '350-701'

# %%
#Export CCNP 350-701 to parquet with filename 350-701-CCNP.parquet in the folder /home/iai/sb7059/git/llm_test/data
ccnp_350_701.to_parquet('/home/iai/sb7059/git/llm_test/data/350-701-CCNP.parquet')

# %%
#Keep the rows with NaN values in column image
ccnp_350_701_no_image = ccnp_350_701[ccnp_350_701['image'].isna()]
ccnp_350_701_no_image.to_parquet('/home/iai/sb7059/git/llm_test/data/350-701-CCNP_no_image.parquet')

# %%
ccnp_350_701_no_image
# Out:
#                                               question  \
# 0    Which functions of an SDN architecture require...
# 1    Which two request methods of REST API are vali...
# 2    The main function of northbound APIs in the SD...
# 3    What is a feature of the open platform capabil...
# 5      Which form of attack is launched using botnets?
# ..                                                 ...
# 135  An engineer has been tasked with configuring a...
# 136  An organization uses Cisco FMC to centrally ma...
# 137  An administrator is establishing a new site-to...
# 138  A Cisco FTD engineer is creating a newIKEv2 po...
# 139  What is a functional difference between a Cisc...
#
#                                                choices  answer image     exam
# 0    [SDN controller and the network elements, mana...     [0]   NaN  350-701
# 1                   [put, options, get, push, connect]  [0, 2]   NaN  350-701
# 2    [SDN controller and the cloud, management cons...     [3]   NaN  350-701
# 3    [application adapters, domain integration, int...     [2]   NaN  350-701
# 5                        [TCP flood, DDOS, DOS, virus]     [1]   NaN  350-701
# ..                                                 ...     ...   ...      ...
# 135  [Enable traffic analysis in the Cisco FTD., Im...     [2]   NaN  350-701
# 136  [Change the management port on Cisco FMC so th...     [2]   NaN  350-701
# 137  [crypto isakmp identity address 172.19.20.24, ...     [3]   NaN  350-701
# 138  [Change the encryption to AES* to support all ...     [3]   NaN  350-701
# 139  [The Cisco ASA can be configured for high avai...     [2]   NaN  350-701
#
# [117 rows x 5 columns]
